# %%
# %cd D:\Archive\Courses\20w\Molecular Mechanics and Multiscale Modelling of Materials\project\Code
# Out:
# D:\Archive\Courses\20w\Molecular Mechanics and Multiscale Modelling of Materials\project\Code

# %%
# !lmp_serial -in runfile_.txt
# Out:
# LAMMPS (24 Dec 2020)
# OMP_NUM_THREADS environment is not set. Defaulting to 1 thread. (src/comm.cpp:94)
#   using 1 OpenMP thread(s) per MPI task
# New timer settings: style=off  mode=nosync  timeout=off
# Reading data file ...
#   triclinic box = (0.15616164 -0.019894586 0.011664001) to (26.388638 24.248095 24.423136) with tilt (2.6793175 -1.2997938 0.68796279)
#   1 by 1 by 1 MPI processor grid
#   reading atoms ...
#   1176 atoms
#   scanning bonds ...
#   2 = max bonds/atom
#   scanning angles ...
#   1 = max angles/atom
#   reading bonds ...
#   208 bonds
#   reading angles ...
#   72 angles
# Finding 1-2 1-3 1-4 neighbors ...
#   special bond factors lj:    0        0        0
#   special bond factors coul:  0        0        0
#      2 = max # of 1-2 neighbors
#      1 = max # of 1-3 neighbors
#      1 = max # of 1-4 neighbors
#      2 = max # of special neighbors
#   special bonds CPU = 0.000 seconds
#   read_data CPU = 0.007 seconds
# Finding 1-2 1-3 1-4 neighbors ...
# ...
